# %%
import requests
import pandas as pd

# %%
###
# Enter your task ID here
###
task_id = "f653afd8045541f3ab6e399018ade91d"

# %%
results_url = "https://gnps.ucsd.edu/ProteoSAFe/DownloadResultFile?task={}&file=query_results/msql/merged_query_results.tsv".format(task_id)

# %%
msqlresults_df = pd.read_csv(results_url, sep="\t")

# %%
msqlresults_df
# Out:
#      charge                              filename           i  i_norm  \
# 0         0  J2315_SPE_48_TMP_P1-B-8_01_2657.mzML   7355764.0     1.0
# 1         0  J2315_SPE_48_TMP_P1-B-8_01_2657.mzML    401478.0     1.0
# 2         0  J2315_SPE_48_TMP_P1-B-8_01_2657.mzML   8328318.0     1.0
# 3         0  J2315_SPE_48_TMP_P1-B-8_01_2657.mzML   8142711.0     1.0
# 4         0  J2315_SPE_48_TMP_P1-B-8_01_2657.mzML    293049.0     1.0
# ..      ...                                   ...         ...     ...
# 462       0      J2315_SPE_48_P1-B-4_01_2653.mzML   9962262.0     1.0
# 463       0      J2315_SPE_48_P1-B-4_01_2653.mzML    640802.0     1.0
# 464       0      J2315_SPE_48_P1-B-4_01_2653.mzML   8905959.0     1.0
# 465       0      J2315_SPE_48_P1-B-4_01_2653.mzML  11038575.0     1.0
# 466       0      J2315_SPE_48_P1-B-4_01_2653.mzML   9641337.0     1.0
#
#      i_norm_ms1  ms1scan  mslevel  \
# 0           1.0      182        2
# 1           1.0      182        2
# 2           1.0      191        2
# 3           1.0      200        2
# 4           1.0      218        2
# ..          ...      ...      ...
# 462         1.0     1568        2
# 463         1.0     3152        2
# 464         1.0     3269        2
# 465         1.0     3278        2
# 466         1.0     3287        2
#
#                                          original_path      precmz  \
# 0    MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  291.144806
# 1    MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  500.216675
# 2    MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  291.144928
# 3    MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  291.145020
# 4    MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  500.216675
# ..                                                 ...         ...
# 462  MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  689.434570
# 463  MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  472.290588
# 464  MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  734.398193
# 465  MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  734.398071
# 466  MSV000084945/ccms_peak/Dataset1_1/B.cenocepaci...  734.398193
#
#      query_index        rt  scan
# 0              0  1.023750   183
# 1              0  1.036850   189
# 2              0  1.047317   192
# 3              0  1.071000   201
# 4              0  1.130850   225
# ..           ...       ...   ...
# 462            0  4.625533  1569
# 463            0  8.732583  3153
# 464            0  9.034417  3270
# 465            0  9.057767  3279
# 466            0  9.081167  3288
#
# [467 rows x 12 columns]
